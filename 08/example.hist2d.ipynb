# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.normal(0, 10, size = 1000000)
y = np.random.normal(0, 10, size = 1000000);

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.hist2d(x, y, bins=(100, 100))
plt.colorbar();
